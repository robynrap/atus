# %%
import numpy as np
import pandas as pd

from get_var_labels import get_var_labels

var_labels_df = get_var_labels("atus_data.xml")
# Out:
#          label                                              value var_name
# 0      RECTYPE                                          Household        1
# 1      RECTYPE                                             Person        2
# 2      RECTYPE                                           Activity        3
# 3      RECTYPE                                                Who        4
# 4      RECTYPE                                          Eldercare        5
# 5       REGION                                          Northeast        1
# 6       REGION                                            Midwest        2
# 7       REGION                                              South        3
# 8       REGION                                               West        4
# 9     STATEFIP                                            Alabama       01
# 10    STATEFIP                                             Alaska       02
# ...
